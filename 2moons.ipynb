# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# from pylab import rcParams
# rcParams['figure.figsize'] = 10, 8
# rcParams['figure.dpi'] = 300


from sklearn import cluster, datasets, mixture
from sklearn.preprocessing import StandardScaler

# %%
import numba
from numba import jit

# %%
import sklearn
mu = sklearn.datasets.make_moons(n_samples=50, shuffle=False, noise=None, random_state=None)[0]
# Y = Y[np.argsort(Y[:,0]),]
# Y += np.random.normal(0,0.05, Y.shape)

# %%
Y= np.hstack([mu]*1)

# %%
Y  += np.random.normal(0,0.1, Y.shape)
Y.shape
# Out:
# (50, 2)

# %%
plt.scatter(Y[:,0],Y[:,1])

# %%
plt.plot(Y[:,0],Y[:,1])

# %%
import importlib
import gibbs_sampling as gs

# %%
importlib.reload(gs)

tree = gs.SpanningTree(Y)

# %%
_ = tree.runMCMC(100)
trace = tree.runMCMC(1000)
# Out:
# 99
# 99
# 199
# 299
# 399
# 499
# 599
# 699
# 799
# 899
# 999

# %%
trace_A= [-x[0]@np.diag(1-x[6])@x[0].T for x in trace]

for i in range(len(trace)):
    np.fill_diagonal(trace_A[i],0)

# %%
trace_A[99].sum()
# Out:
# 90.0

# %%
mean_mst = np.array(trace_A).mean(0)

# %%
plt.imshow(mean_mst, vmin=0,vmax=1,cmap='jet')
plt.colorbar()

# %%
# import

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 8
rcParams['figure.dpi'] = 300

# %%
c_vec = ['lightblue']*50
# c_vec[3] = 'red'
# c_vec[2] = 'yellow'
# c_vec[4] = 'purple'

# %%
trace_A[99].sum()
# Out:
# 90.0

# %%
# a= trace_A[100]


# g = igraph.Graph.Adjacency((a > 0).tolist())
# g.to_undirected()

# layout = zip(list(-Y[:,0]), list(Y[:,1])) 
# out =  igraph.plot(g, layout = layout, vertex_color = c_vec)

# out.save('2moon_tree1.png')
# # out

# %%
# igraph.write(g, "2moon_tree1.graphml",format = "graphml")

# %%
# a= mean_mst


# g = igraph.Graph.Adjacency((a).tolist(),weighted=True)
# g.to_undirected()

# layout = zip(list(-Y[:,0]), list(Y[:,1])) 
# out =  igraph.plot(g, layout = layout, vertex_color = c_vec)

# # out.save('2moon_tree1.png')
# out

# %%
import networkx as nx

# %%
# Y= Y*100

# %%
Y[:,0]*= 0.8

# %%
# plt.imshow(mean_mst, cmap='jet',vmin=0,vmax=1)

# %%
g_nx= nx.Graph(mean_mst)
for i in range(Y.shape[0]):
    g_nx.nodes[i].update({"viz":{"position": {"x": Y[i,0], "y": Y[i,1], "z": 0},
                                'color': {'r': 192, 'g': 192, 'b': 192, 'a': 0},
                                 'size': "4"
                                }})

# nx.draw(g_nx)

nx.write_gexf(g_nx, "2moon_tree1.gexf")

nx.draw(g_nx,pos=Y[:,:2])

# %%
g_nx= nx.Graph( trace_A[0])
for i in range(Y.shape[0]):
    g_nx.nodes[i].update({"viz":{"position": {"x": Y[i,0], "y": Y[i,1], "z": 0},
                                'color': {'r': 192, 'g': 192, 'b': 192, 'a': 0},
                                 'size': "4"
                                }})

# nx.draw(g_nx)

# nx.write_gexf(g_nx, "2moon_tree1.gexf")

nx.draw(g_nx,pos=mu)

# %%
Y.shape
# Out:
# (50, 2)

# %%
g_nx= nx.Graph(tree.mst0)
for i in range(Y.shape[0]):
    g_nx.nodes[i].update({"viz":{"position": {"x": Y[i,0], "y": Y[i,1], "z": 0},
                                'color': {'r': 192, 'g': 192, 'b': 192, 'a': 0},
                                 'size': "4"
                                }})

# nx.draw(g_nx)

# nx.write_gexf(g_nx, "2moon_tree2.gexf")

nx.draw(g_nx, pos=mu)
