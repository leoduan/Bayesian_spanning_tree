# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pickle as pkl
T, Y_all = pkl.load(open("time_series.pkl","rb"))

# encoding = (T>=0) & (T<2000)
# Y= Y_all[:,encoding]

pick = (T>=0) & (T<1000)
Y= Y_all[:,pick]


Y.shape
# Out:
# (128, 256)

# %%
for j in range(10):
    plt.plot(Y[:,j])
